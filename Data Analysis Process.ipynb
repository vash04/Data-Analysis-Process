# %% [markdown]
# # Data Gathering

# %%
import pandas as pd

# %%
pd.read_csv("bollywood.csv")
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]

# %%
pd.read_csv("bollywood.csv", sep="/t")
# Out:
# C:\Users\joshi\AppData\Local\Temp\ipykernel_17260\1709172674.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   pd.read_csv("bollywood.csv", sep="/t")
#                                             movie,lead
# 0               Uri: The Surgical Strike,Vicky Kaushal
# 1                            Battalion 609,Vicky Ahuja
# 2     The Accidental Prime Minister (film),Anupam Kher
# 3                        Why Cheat India,Emraan Hashmi
# 4                     Evening Shadows,Mona Ambegaonkar
# ...                                                ...
# 1495             Hum Tumhare Hain Sanam,Shah Rukh Khan
# 1496              Aankhen (2002 film),Amitabh Bachchan
# 1497                      Saathiya (film),Vivek Oberoi
# 1498                         Company (film),Ajay Devgn
# ...

# %%
pd.read_csv("bollywood.csv", sep="/t", names=["film", "hero"])
# Out:
# C:\Users\joshi\AppData\Local\Temp\ipykernel_17260\1253286248.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   pd.read_csv("bollywood.csv", sep="/t", names=["film", "hero"])
#                                                   film  hero
# 0                                           movie,lead   NaN
# 1               Uri: The Surgical Strike,Vicky Kaushal   NaN
# 2                            Battalion 609,Vicky Ahuja   NaN
# 3     The Accidental Prime Minister (film),Anupam Kher   NaN
# 4                        Why Cheat India,Emraan Hashmi   NaN
# ...                                                ...   ...
# 1496             Hum Tumhare Hain Sanam,Shah Rukh Khan   NaN
# 1497              Aankhen (2002 film),Amitabh Bachchan   NaN
# ...

# %%
pd.read_csv("bollywood.csv", header=1)
# Out:
#                   Uri: The Surgical Strike         Vicky Kaushal
# 0                            Battalion 609           Vicky Ahuja
# 1     The Accidental Prime Minister (film)           Anupam Kher
# 2                          Why Cheat India         Emraan Hashmi
# 3                          Evening Shadows      Mona Ambegaonkar
# 4                              Soni (film)  Geetika Vidya Ohlyan
# ...                                    ...                   ...
# 1494                Hum Tumhare Hain Sanam        Shah Rukh Khan
# 1495                   Aankhen (2002 film)      Amitabh Bachchan
# 1496                       Saathiya (film)          Vivek Oberoi
# 1497                        Company (film)            Ajay Devgn
# 1498                  Awara Paagal Deewana          Akshay Kumar
#
# [1499 rows x 2 columns]

# %%
pd.read_csv("bollywood.csv", usecols=["movie"])
# Out:
#                                      movie
# 0                 Uri: The Surgical Strike
# 1                            Battalion 609
# 2     The Accidental Prime Minister (film)
# 3                          Why Cheat India
# 4                          Evening Shadows
# ...                                    ...
# 1495                Hum Tumhare Hain Sanam
# 1496                   Aankhen (2002 film)
# 1497                       Saathiya (film)
# 1498                        Company (film)
# 1499                  Awara Paagal Deewana
#
# [1500 rows x 1 columns]

# %%
pd.read_csv("bollywood.csv", skiprows=[0,4])
# Out:
#                   Uri: The Surgical Strike         Vicky Kaushal
# 0                            Battalion 609           Vicky Ahuja
# 1     The Accidental Prime Minister (film)           Anupam Kher
# 2                          Evening Shadows      Mona Ambegaonkar
# 3                              Soni (film)  Geetika Vidya Ohlyan
# 4                            Fraud Saiyaan          Arshad Warsi
# ...                                    ...                   ...
# 1493                Hum Tumhare Hain Sanam        Shah Rukh Khan
# 1494                   Aankhen (2002 film)      Amitabh Bachchan
# 1495                       Saathiya (film)          Vivek Oberoi
# 1496                        Company (film)            Ajay Devgn
# 1497                  Awara Paagal Deewana          Akshay Kumar
#
# [1498 rows x 2 columns]

# %%
pd.read_csv("bollywood.csv", nrows=10)
# Out:
#                                   movie                  lead
# 0              Uri: The Surgical Strike         Vicky Kaushal
# 1                         Battalion 609           Vicky Ahuja
# 2  The Accidental Prime Minister (film)           Anupam Kher
# 3                       Why Cheat India         Emraan Hashmi
# 4                       Evening Shadows      Mona Ambegaonkar
# 5                           Soni (film)  Geetika Vidya Ohlyan
# 6                         Fraud Saiyaan          Arshad Warsi
# 7                            Bombairiya          Radhika Apte
# 8      Manikarnika: The Queen of Jhansi        Kangana Ranaut
# 9                      Thackeray (film)   Nawazuddin Siddiqui

# %%
pd.read_csv("kohli_ipl.csv").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   match_no  215 non-null    int64
#  1   runs      215 non-null    int64
# dtypes: int64(2)
# memory usage: 3.5 KB

# %%
pd.read_csv("kohli_ipl.csv", dtype={"runs":int})
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
pd.read_csv("ipl-matches.csv").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
pd.read_csv("ipl-matches.csv", parse_dates=["Date"]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    datetime64[ns]
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
def rename(name):
    if name=="Rajasthan Royals":
        return "RR"
    else:
        return name

# %%
rename("Rajasthan Royals")
# Out:
# 'RR'

# %%
pd.read_csv("ipl-matches.csv", converters={"Team1":rename})
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0                             RR               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
pd.read_csv("ipl-matches.csv", na_values=["MatchNumber"])
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
dfs=pd.read_csv("ipl-matches.csv", chunksize=100)

# %%
for chunks in dfs:
    print(chunks.shape)
# Out:
# (100, 20)
# (100, 20)
# (100, 20)
# (100, 20)
# (100, 20)
# (100, 20)
# (100, 20)
# (100, 20)
# (100, 20)
# (50, 20)

# %%
pd.read_excel("imf report.xlsx").head()
# Out:
#   WEO Country Code  ISO WEO Subject Code      Country  \
# 0              512  AFG           NGDP_R  Afghanistan
# 1              512  AFG        NGDP_RPCH  Afghanistan
# 2              512  AFG             NGDP  Afghanistan
# 3              512  AFG            NGDPD  Afghanistan
# 4              512  AFG           PPPGDP  Afghanistan
#
#                         Subject Descriptor  \
# 0  Gross domestic product, constant prices
# 1  Gross domestic product, constant prices
# 2   Gross domestic product, current prices
# 3   Gross domestic product, current prices
# 4   Gross domestic product, current prices
#
#                                        Subject Notes  \
# 0  Expressed in billions of national currency uni...
# 1  Annual percentages of constant price GDP are y...
# 2  Expressed in billions of national currency uni...
# 3  Values are based upon GDP in national currency...
# 4  These data form the basis for the country weig...
#
# ...

# %%
pd.read_csv("top_level.txt", sep="/t")
# Out:
# C:\Users\joshi\AppData\Local\Temp\ipykernel_17260\3241347405.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   pd.read_csv("top_level.txt", sep="/t")
# Empty DataFrame
# Columns: [trio_websocket]
# Index: []

# %%
pd.read_json("train.json.zip").head()
# Out:
#       id      cuisine                                        ingredients
# 0  10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213       indian                [water, vegetable oil, wheat, salt]
# 4  13162       indian  [black pepper, shallots, cornflour, cayenne pe...

# %%
# !pip install mysql.connector

# %%
import mysql.connector

# %%
# not getting it right now

# %%
df=pd.DataFrame()

# %%
df=pd.read_csv("deliveries.csv")
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
tempdf=df.groupby("batsman")["batsman_runs"].sum().reset_index()
tempdf.head()
# Out:
#           batsman  batsman_runs
# 0  A Ashish Reddy           280
# 1      A Chandila             4
# 2        A Chopra            53
# 3     A Choudhary            25
# 4     A Dananjaya             4

# %%
tempdf.to_csv("batsman_runs.csv", index=False)

# %%
tempdf2=df.pivot_table(index="batsman", columns="bowling_team", values="batsman_runs", aggfunc="sum")
tempdf2.head()
# Out:
# bowling_team    Chennai Super Kings  Deccan Chargers  Delhi Capitals  \
# batsman
# A Ashish Reddy                 45.0              NaN             NaN
# A Chandila                      NaN              0.0             NaN
# A Chopra                        NaN             35.0             NaN
# A Choudhary                     NaN              NaN             NaN
# A Dananjaya                     NaN              NaN             NaN
#
# bowling_team    Delhi Daredevils  Gujarat Lions  Kings XI Punjab  \
# batsman
# A Ashish Reddy              36.0            NaN             37.0
# A Chandila                   NaN            NaN              NaN
# A Chopra                    13.0            NaN              2.0
# A Choudhary                  NaN           15.0              4.0
# A Dananjaya                  4.0            NaN              NaN
#
# bowling_team    Kochi Tuskers Kerala  Kolkata Knight Riders  Mumbai Indians  \
# batsman
# ...

# %%
tempdf2.to_csv("batsman_runs_per_teams.csv")

# %%
tempdf.to_excel("batsman_runs.xlsx", sheet_name="batsman_runs")

# %%
tempdf3=df[df["batsman_runs"]==6].pivot_table(index="over", columns="ball", values="batsman_runs", aggfunc="count")
tempdf3
# Out:
# ball     1      2      3      4      5      6     7    8    9
# over
# 1      7.0   12.0   27.0   31.0   24.0   20.0  12.0  1.0  NaN
# 2     26.0   30.0   35.0   43.0   45.0   42.0  10.0  5.0  NaN
# 3     63.0   46.0   57.0   52.0   48.0   58.0   8.0  2.0  1.0
# 4     49.0   61.0   51.0   81.0   54.0   53.0  11.0  1.0  NaN
# 5     54.0   56.0   82.0   64.0   62.0   60.0  10.0  2.0  NaN
# 6     61.0   82.0   44.0   65.0   56.0   66.0  11.0  1.0  NaN
# 7     27.0   45.0   34.0   44.0   51.0   28.0   3.0  3.0  NaN
# 8     44.0   47.0   55.0   49.0   53.0   39.0   7.0  NaN  NaN
# 9     70.0   56.0   56.0   58.0   52.0   35.0  11.0  NaN  1.0
# 10    43.0   38.0   60.0   43.0   52.0   54.0   9.0  1.0  NaN
# 11    59.0   70.0   62.0   54.0   61.0   56.0   8.0  NaN  NaN
# 12    70.0   58.0   72.0   63.0   65.0   52.0  11.0  1.0  NaN
# 13    67.0   87.0   58.0   80.0   75.0   65.0  10.0  2.0  NaN
# 14    83.0   85.0   79.0   74.0   65.0   71.0   7.0  3.0  NaN
# ...

# %%
tempdf3.to_html("sixes_heatmap.html")

# %%
tempdf4=df.groupby(["batsman", "bowling_team"])["batsman_runs"].sum().reset_index()
tempdf4.head()
# Out:
#           batsman           bowling_team  batsman_runs
# 0  A Ashish Reddy    Chennai Super Kings            45
# 1  A Ashish Reddy       Delhi Daredevils            36
# 2  A Ashish Reddy        Kings XI Punjab            37
# 3  A Ashish Reddy  Kolkata Knight Riders            17
# 4  A Ashish Reddy         Mumbai Indians            27

# %%
tempdf4.to_json("batsman_runs_per_team.json")

# %%
#api data gathering and web scrapping has to be done

# %% [markdown]
# # data assessing and cleaning

# %%
patients=pd.read_csv("patients.csv")
treatment=pd.read_csv("treatments.csv")
adverse_reaction=pd.read_csv("adverse_reactions.csv")
treatment_cut=pd.read_csv("treatments_cut.csv")

# %%
patients.head()
# Out:
#    patient_id assigned_sex given_name  surname                    address  \
# 0           1       female        Zoe  Wellish       576 Brown Bear Drive
# 1           2       female     Pamela     Hill  2370 University Hill Road
# 2           3         male        Jae   Debord      1493 Poling Farm Road
# 3           4         male       Liêm     Phan        2335 Webster Street
# 4           5         male        Tim  Neudorf       1428 Turkey Pen Lane
#
#                 city       state  zip_code        country  \
# 0  Rancho California  California   92390.0  United States
# 1          Armstrong    Illinois   61812.0  United States
# 2               York    Nebraska   68467.0  United States
# 3         Woodbridge          NJ    7095.0  United States
# 4             Dothan          AL   36303.0  United States
#
#                                       contact  birthdate  weight  height   bmi
# 0        951-719-9170ZoeWellish@superrito.com  7/10/1976   121.7      66  19.6
# ...

# %%
treatment.head()
# Out:
#   given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0   veronika    jindrová  41u - 48u          -         7.63       7.20
# 1     elliot  richardson          -  40u - 45u         7.56       7.09
# 2   yukitaka    takenaka          -  39u - 36u         7.68       7.25
# 3       skye  gormanston  33u - 36u          -         7.97       7.62
# 4     alissa      montez          -  33u - 29u         7.78       7.46
#
#    hba1c_change
# 0           NaN
# 1          0.97
# 2           NaN
# 3          0.35
# 4          0.32

# %%
adverse_reaction.head()
# Out:
#   given_name     surname           adverse_reaction
# 0      berta  napolitani  injection site discomfort
# 1       lena        baer               hypoglycemia
# 2     joseph         day               hypoglycemia
# 3     flavia  fiorentino                      cough
# 4    manouck     wubbels          throat irritation

# %%
treatment_cut.head()
# Out:
#   given_name    surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0      jožka  resanovič  22u - 30u          -         7.56       7.22
# 1  inunnguaq   heilmann  57u - 67u          -         7.85       7.45
# 2      alwin   svensson  36u - 39u          -         7.78       7.34
# 3        thể      lương          -  61u - 64u         7.64       7.22
# 4     amanda    ribeiro  36u - 44u          -         7.85       7.47
#
#    hba1c_change
# 0          0.34
# 1           NaN
# 2           NaN
# 3          0.92
# 4          0.38

# %%
# write the summary of the data

# %%
# write column discription of every column of all table in the database and additional assessments

# %%
with pd.ExcelWriter("clinical_trials.xlsx") as writer:
    patients.to_excel(writer, sheet_name="patients")
    treatment.to_excel(writer, sheet_name="treatment")
    treatment_cut.to_excel(writer, sheet_name="treatment_cut")
    adverse_reaction.to_excel(writer, sheet_name="adverse_reaction")

# %% [markdown]
# dirty data:
#
# patients:
# - patient_id == 9 has misspelt name "Dsvid" instead of "David" (accuracy)
# - state col contains some full form some abberivation data (consistency)
# - zipcode col has entries with 4 digit instead of 5 (validity)
# - address, city, state, zip_code, country, contact all these col contains 12 same null values (completeness)
# - assigned_sex, zip_code, birthdate have incorrect datatypes (validity)
# - 5 duplicate row with name "John Doe" (accuracy)
# - 1 patient has weight 48.8 pound apperantly not possible (accuracy)
# - 1 patient has height 27 inches not possible (accuracy)
#
# treatment and treatment_cut:
# - given_name and surname col in lower case (consistency)
# - remove "u" from auralin and novodra col (validity)
# - auralin and novodra col has - instead of NaN (validity)
# - hba1c_change has 109 null values in treatment and 28 in treatment_cut (completion)
# - one duplicate row with the name "joseph day" (accuracy)
# - 9.xy is written instead of 4.xy in hba1c_change col (accuracy)
#
# adverse_reaction:
# - given_name and surname are in lower case (consistency)

# %% [markdown]
# messy data:
#
# patients:
# - phone and email in single col "contact"
#
# treatment and treatment_cut:
# - auralin and novodra both col should be split in two (start and end)
#
# adverse_reaction:
# - table should not exist independently and adverse_reaction col should be concat in treatment

# %%
# head, tail, sample, info, isnull, duplicate and describe on all col

# %%
patients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   patient_id    503 non-null    int64
#  1   assigned_sex  503 non-null    object
#  2   given_name    503 non-null    object
#  3   surname       503 non-null    object
#  4   address       491 non-null    object
#  5   city          491 non-null    object
#  6   state         491 non-null    object
#  7   zip_code      491 non-null    float64
#  8   country       491 non-null    object
#  9   contact       491 non-null    object
#  10  birthdate     503 non-null    object
#  11  weight        503 non-null    float64
#  12  height        503 non-null    int64
#  13  bmi           503 non-null    float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 55.1+ KB

# %%
patients[patients["address"].isnull()]
# Out:
#      patient_id assigned_sex given_name      surname address city state  \
# 209         210       female     Lalita  Eldarkhanov     NaN  NaN   NaN
# 219         220         male         Mỹ        Quynh     NaN  NaN   NaN
# 230         231       female  Elisabeth      Knudsen     NaN  NaN   NaN
# 234         235       female    Martina    Tománková     NaN  NaN   NaN
# 242         243         male       John      O'Brian     NaN  NaN   NaN
# 249         250         male   Benjamin       Mehler     NaN  NaN   NaN
# 257         258         male        Jin         Kung     NaN  NaN   NaN
# 264         265       female   Wafiyyah       Asfour     NaN  NaN   NaN
# 269         270       female     Flavia   Fiorentino     NaN  NaN   NaN
# 278         279       female   Generosa        Cabán     NaN  NaN   NaN
# 286         287         male      Lewis         Webb     NaN  NaN   NaN
# 296         297       female        Chỉ          Lâm     NaN  NaN   NaN
#
# ...

# %%
treatment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    280 non-null    object
#  1   surname       280 non-null    object
#  2   auralin       280 non-null    object
#  3   novodra       280 non-null    object
#  4   hba1c_start   280 non-null    float64
#  5   hba1c_end     280 non-null    float64
#  6   hba1c_change  171 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 15.4+ KB

# %%
treatment_cut.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    70 non-null     object
#  1   surname       70 non-null     object
#  2   auralin       70 non-null     object
#  3   novodra       70 non-null     object
#  4   hba1c_start   70 non-null     float64
#  5   hba1c_end     70 non-null     float64
#  6   hba1c_change  42 non-null     float64
# dtypes: float64(3), object(4)
# memory usage: 4.0+ KB

# %%
adverse_reaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   given_name        34 non-null     object
#  1   surname           34 non-null     object
#  2   adverse_reaction  34 non-null     object
# dtypes: object(3)
# memory usage: 948.0+ bytes

# %%
patients[patients.duplicated(subset=["given_name", "surname"])]
# Out:
#      patient_id assigned_sex given_name surname          address      city  \
# 229         230         male       John     Doe  123 Main Street  New York
# 237         238         male       John     Doe  123 Main Street  New York
# 244         245         male       John     Doe  123 Main Street  New York
# 251         252         male       John     Doe  123 Main Street  New York
# 277         278         male       John     Doe  123 Main Street  New York
#
#     state  zip_code        country                      contact birthdate  \
# 229    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 237    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 244    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 251    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 277    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
#
#      weight  height   bmi
# 229   180.0      72  24.4
# ...

# %%
treatment[treatment.duplicated()]
# Out:
#     given_name surname    auralin novodra  hba1c_start  hba1c_end  \
# 136     joseph     day  29u - 36u       -          7.7       7.19
#
#      hba1c_change
# 136           NaN

# %%
treatment_cut[treatment_cut.duplicated(subset=["given_name", "surname"])]
# Out:
# Empty DataFrame
# Columns: [given_name, surname, auralin, novodra, hba1c_start, hba1c_end, hba1c_change]
# Index: []

# %%
adverse_reaction.duplicated(subset=["given_name", "surname"]).sum()
# Out:
# 0

# %%
patients.describe()
# Out:
#        patient_id      zip_code      weight      height         bmi
# count  503.000000    491.000000  503.000000  503.000000  503.000000
# mean   252.000000  49084.118126  173.434990   66.634195   27.483897
# std    145.347859  30265.807442   33.916741    4.411297    5.276438
# min      1.000000   1002.000000   48.800000   27.000000   17.100000
# 25%    126.500000  21920.500000  149.300000   63.000000   23.300000
# 50%    252.000000  48057.000000  175.300000   67.000000   27.200000
# 75%    377.500000  75679.000000  199.500000   70.000000   31.750000
# max    503.000000  99701.000000  255.900000   79.000000   37.700000

# %%
patients[patients["weight"]==48.8]
# Out:
#      patient_id assigned_sex given_name   surname              address  \
# 210         211       female    Camilla  Zaitseva  4689 Briarhill Lane
#
#         city state  zip_code        country  \
# 210  Wooster    OH   44691.0  United States
#
#                                        contact   birthdate  weight  height  \
# 210  330-202-2145CamillaZaitseva@superrito.com  11/26/1938    48.8      63
#
#       bmi
# 210  19.1

# %%
patients[patients["height"]==27]
# Out:
#    patient_id assigned_sex given_name  surname               address    city  \
# 4           5         male        Tim  Neudorf  1428 Turkey Pen Lane  Dothan
#
#   state  zip_code        country                          contact  birthdate  \
# 4    AL   36303.0  United States  334-515-7487TimNeudorf@cuvox.de  2/18/1928
#
#    weight  height   bmi
# 4   192.3      27  26.1

# %%
treatment.describe()
# Out:
#        hba1c_start   hba1c_end  hba1c_change
# count   280.000000  280.000000    171.000000
# mean      7.985929    7.589286      0.546023
# std       0.568638    0.569672      0.279555
# min       7.500000    7.010000      0.200000
# 25%       7.660000    7.270000      0.340000
# 50%       7.800000    7.420000      0.380000
# 75%       7.970000    7.570000      0.920000
# max       9.950000    9.580000      0.990000

# %%
treatment.sort_values("hba1c_change", na_position="first")
# Out:
#     given_name      surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0     veronika     jindrová  41u - 48u          -         7.63       7.20
# 2     yukitaka     takenaka          -  39u - 36u         7.68       7.25
# 8        saber       ménard          -  54u - 54u         8.08       7.70
# 9         asia      woźniak  30u - 36u          -         7.76       7.37
# 10      joseph          day  29u - 36u          -         7.70       7.19
# ..         ...          ...        ...        ...          ...        ...
# 49     jackson      addison          -  42u - 42u         7.99       7.51
# 17        gina         cain          -  36u - 36u         7.88       7.40
# 32       laura  ehrlichmann          -  43u - 40u         7.95       7.46
# 245         wu         sung          -  47u - 48u         7.61       7.12
# 138    giovana        rocha          -  23u - 21u         7.87       7.38
#
#      hba1c_change
# 0             NaN
# 2             NaN
# 8             NaN
# ...

# %%
treatment_cut.describe()
# Out:
#        hba1c_start  hba1c_end  hba1c_change
# count    70.000000  70.000000     42.000000
# mean      7.838000   7.443143      0.518810
# std       0.423007   0.418706      0.270719
# min       7.510000   7.020000      0.280000
# 25%       7.640000   7.232500      0.340000
# 50%       7.730000   7.345000      0.370000
# 75%       7.860000   7.467500      0.907500
# max       9.910000   9.460000      0.970000

# %%
patients_df=patients.copy()
treatment_df=treatment.copy()
treatment_cut_df=treatment_cut.copy()
adverse_reaction_df=adverse_reaction.copy()

# %%
# define, code and test (im doing all three steps without markdowns)

# %%
patients_df[patients_df["address"].isnull()]
# Out:
#      patient_id assigned_sex given_name      surname address city state  \
# 209         210       female     Lalita  Eldarkhanov     NaN  NaN   NaN
# 219         220         male         Mỹ        Quynh     NaN  NaN   NaN
# 230         231       female  Elisabeth      Knudsen     NaN  NaN   NaN
# 234         235       female    Martina    Tománková     NaN  NaN   NaN
# 242         243         male       John      O'Brian     NaN  NaN   NaN
# 249         250         male   Benjamin       Mehler     NaN  NaN   NaN
# 257         258         male        Jin         Kung     NaN  NaN   NaN
# 264         265       female   Wafiyyah       Asfour     NaN  NaN   NaN
# 269         270       female     Flavia   Fiorentino     NaN  NaN   NaN
# 278         279       female   Generosa        Cabán     NaN  NaN   NaN
# 286         287         male      Lewis         Webb     NaN  NaN   NaN
# 296         297       female        Chỉ          Lâm     NaN  NaN   NaN
#
# ...

# %%
patients_df.fillna("no data", inplace=True)

# %%
patients_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   patient_id    503 non-null    int64
#  1   assigned_sex  503 non-null    object
#  2   given_name    503 non-null    object
#  3   surname       503 non-null    object
#  4   address       503 non-null    object
#  5   city          503 non-null    object
#  6   state         503 non-null    object
#  7   zip_code      503 non-null    object
#  8   country       503 non-null    object
#  9   contact       503 non-null    object
#  10  birthdate     503 non-null    object
#  11  weight        503 non-null    float64
#  12  height        503 non-null    int64
#  13  bmi           503 non-null    float64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 55.1+ KB

# %%
treatment_df["hba1c_change"]=treatment_df["hba1c_start"]-treatment_df["hba1c_end"]

# %%
treatment_df
# Out:
#     given_name       surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0     veronika      jindrová  41u - 48u          -         7.63       7.20
# 1       elliot    richardson          -  40u - 45u         7.56       7.09
# 2     yukitaka      takenaka          -  39u - 36u         7.68       7.25
# 3         skye    gormanston  33u - 36u          -         7.97       7.62
# 4       alissa        montez          -  33u - 29u         7.78       7.46
# ..         ...           ...        ...        ...          ...        ...
# 275     albina      zetticci  45u - 51u          -         7.93       7.73
# 276       john   teichelmann          -  49u - 49u         7.90       7.58
# 277     mathea       lillebø  23u - 36u          -         9.04       8.67
# 278     vallie        prince  31u - 38u          -         7.64       7.28
# 279     samúel  guðbrandsson  53u - 56u          -         8.00       7.64
#
#      hba1c_change
# 0            0.43
# 1            0.47
# ...

# %%
treatment_cut_df["hba1c_change"]=treatment_cut_df["hba1c_start"]-treatment_cut_df["hba1c_end"]

# %%
treatment_cut_df
# Out:
#    given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0       jožka   resanovič  22u - 30u          -         7.56       7.22
# 1   inunnguaq    heilmann  57u - 67u          -         7.85       7.45
# 2       alwin    svensson  36u - 39u          -         7.78       7.34
# 3         thể       lương          -  61u - 64u         7.64       7.22
# 4      amanda     ribeiro  36u - 44u          -         7.85       7.47
# ..        ...         ...        ...        ...          ...        ...
# 65     rovzan     kishiev  32u - 37u          -         7.75       7.41
# 66      jakob    jakobsen          -  28u - 26u         7.96       7.51
# 67      bernd   schneider  48u - 56u          -         7.74       7.44
# 68      berta  napolitani          -  42u - 44u         7.68       7.21
# 69     armina       sauvé  36u - 46u          -         7.86       7.40
#
#     hba1c_change
# 0           0.34
# 1           0.40
# 2           0.44
# 3           0.42
# ...

# %%
import re

# %%
patients["contact"]
# Out:
# 0                 951-719-9170ZoeWellish@superrito.com
# 1                PamelaSHill@cuvox.de+1 (217) 569-3204
# 2                     402-363-6804JaeMDebord@gustr.com
# 3           PhanBaLiem@jourrapide.com+1 (732) 636-8246
# 4                      334-515-7487TimNeudorf@cuvox.de
#                             ...
# 498        207-477-0579MustafaLindstrom@jourrapide.com
# 499                 928-284-4492RumanBisliev@gustr.com
# 500              816-223-6007JinkedeKeizer@teleworm.us
# 501    ChidaluOnyekaozulu@jourrapide.com1 360 443 2060
# 502               PatrickGersten@rhyta.com402-848-4923
# Name: contact, Length: 503, dtype: object

# %%
# i have to find a solution for this

# %%
treatment_df=pd.concat([treatment_df, treatment_cut])
treatment_df
# Out:
#    given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0    veronika    jindrová  41u - 48u          -         7.63       7.20
# 1      elliot  richardson          -  40u - 45u         7.56       7.09
# 2    yukitaka    takenaka          -  39u - 36u         7.68       7.25
# 3        skye  gormanston  33u - 36u          -         7.97       7.62
# 4      alissa      montez          -  33u - 29u         7.78       7.46
# ..        ...         ...        ...        ...          ...        ...
# 65     rovzan     kishiev  32u - 37u          -         7.75       7.41
# 66      jakob    jakobsen          -  28u - 26u         7.96       7.51
# 67      bernd   schneider  48u - 56u          -         7.74       7.44
# 68      berta  napolitani          -  42u - 44u         7.68       7.21
# 69     armina       sauvé  36u - 46u          -         7.86       7.40
#
#     hba1c_change
# 0           0.43
# 1           0.47
# 2           0.43
# 3           0.35
# ...

# %%
tdf=treatment_df.melt(id_vars=["given_name", "surname" ,"hba1c_start" ,"hba1c_end" ,"hba1c_change"], var_name="type", value_name="dosage_range")
tdf.head()
# Out:
#   given_name     surname  hba1c_start  hba1c_end  hba1c_change     type  \
# 0   veronika    jindrová         7.63       7.20          0.43  auralin
# 1     elliot  richardson         7.56       7.09          0.47  auralin
# 2   yukitaka    takenaka         7.68       7.25          0.43  auralin
# 3       skye  gormanston         7.97       7.62          0.35  auralin
# 4     alissa      montez         7.78       7.46          0.32  auralin
#
#   dosage_range
# 0    41u - 48u
# 1            -
# 2            -
# 3    33u - 36u
# 4            -

# %%
tdf=tdf[tdf["dosage_range"]!="-"]
tdf.head()
# Out:
#   given_name     surname  hba1c_start  hba1c_end  hba1c_change     type  \
# 0   veronika    jindrová         7.63       7.20          0.43  auralin
# 3       skye  gormanston         7.97       7.62          0.35  auralin
# 6     sophia      haugen         7.65       7.27          0.38  auralin
# 7      eddie      archer         7.89       7.55          0.34  auralin
# 9       asia     woźniak         7.76       7.37          0.39  auralin
#
#   dosage_range
# 0    41u - 48u
# 3    33u - 36u
# 6    37u - 42u
# 7    31u - 38u
# 9    30u - 36u

# %%
tdf["dosage_start"]=tdf["dosage_range"].str.split("-").str.get(0)
tdf["dosage_end"]=tdf["dosage_range"].str.split("-").str.get(1)
tdf.head()
# Out:
#   given_name     surname  hba1c_start  hba1c_end  hba1c_change     type  \
# 0   veronika    jindrová         7.63       7.20          0.43  auralin
# 3       skye  gormanston         7.97       7.62          0.35  auralin
# 6     sophia      haugen         7.65       7.27          0.38  auralin
# 7      eddie      archer         7.89       7.55          0.34  auralin
# 9       asia     woźniak         7.76       7.37          0.39  auralin
#
#   dosage_range dosage_start dosage_end
# 0    41u - 48u         41u         48u
# 3    33u - 36u         33u         36u
# 6    37u - 42u         37u         42u
# 7    31u - 38u         31u         38u
# 9    30u - 36u         30u         36u

# %%
tdf.drop(columns="dosage_range", inplace=True)

# %%
tdf
# Out:
#       given_name     surname  hba1c_start  hba1c_end  hba1c_change     type  \
# 0       veronika    jindrová         7.63       7.20          0.43  auralin
# 3           skye  gormanston         7.97       7.62          0.35  auralin
# 6         sophia      haugen         7.65       7.27          0.38  auralin
# 7          eddie      archer         7.89       7.55          0.34  auralin
# 9           asia     woźniak         7.76       7.37          0.39  auralin
# ..           ...         ...          ...        ...           ...      ...
# 688  christopher    woodward         7.51       7.06          0.95  novodra
# 690        maret    sultygov         7.67       7.30           NaN  novodra
# 694        lixue       hsueh         9.21       8.80          0.91  novodra
# 696        jakob    jakobsen         7.96       7.51          0.95  novodra
# 698        berta  napolitani         7.68       7.21           NaN  novodra
#
#     dosage_start dosage_end
# ...

# %%
tdf["dosage_start"]=tdf["dosage_start"].str.replace("u", "")

# %%
tdf["dosage_end"]=tdf["dosage_end"].str.replace("u", "")

# %%
tdf.head()
# Out:
#   given_name     surname  hba1c_start  hba1c_end  hba1c_change     type  \
# 0   veronika    jindrová         7.63       7.20          0.43  auralin
# 3       skye  gormanston         7.97       7.62          0.35  auralin
# 6     sophia      haugen         7.65       7.27          0.38  auralin
# 7      eddie      archer         7.89       7.55          0.34  auralin
# 9       asia     woźniak         7.76       7.37          0.39  auralin
#
#   dosage_start dosage_end
# 0          41          48
# 3          33          36
# 6          37          42
# 7          31          38
# 9          30          36

# %%
tdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 350 entries, 0 to 698
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    350 non-null    object
#  1   surname       350 non-null    object
#  2   hba1c_start   350 non-null    float64
#  3   hba1c_end     350 non-null    float64
#  4   hba1c_change  322 non-null    float64
#  5   type          350 non-null    object
#  6   dosage_start  350 non-null    object
#  7   dosage_end    350 non-null    object
# dtypes: float64(3), object(5)
# memory usage: 24.6+ KB

# %%
tdf["dosage_start"]=tdf["dosage_start"].astype("int")
tdf["dosage_end"]=tdf["dosage_end"].astype("int")
tdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 350 entries, 0 to 698
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    350 non-null    object
#  1   surname       350 non-null    object
#  2   hba1c_start   350 non-null    float64
#  3   hba1c_end     350 non-null    float64
#  4   hba1c_change  322 non-null    float64
#  5   type          350 non-null    object
#  6   dosage_start  350 non-null    int32
#  7   dosage_end    350 non-null    int32
# dtypes: float64(3), int32(2), object(3)
# memory usage: 21.9+ KB

# %%
tdf=tdf.merge(adverse_reaction, how="left", on=["given_name", "surname"])
tdf
# Out:
#       given_name     surname  hba1c_start  hba1c_end  hba1c_change     type  \
# 0       veronika    jindrová         7.63       7.20          0.43  auralin
# 1           skye  gormanston         7.97       7.62          0.35  auralin
# 2         sophia      haugen         7.65       7.27          0.38  auralin
# 3          eddie      archer         7.89       7.55          0.34  auralin
# 4           asia     woźniak         7.76       7.37          0.39  auralin
# ..           ...         ...          ...        ...           ...      ...
# 345  christopher    woodward         7.51       7.06          0.95  novodra
# 346        maret    sultygov         7.67       7.30           NaN  novodra
# 347        lixue       hsueh         9.21       8.80          0.91  novodra
# 348        jakob    jakobsen         7.96       7.51          0.95  novodra
# 349        berta  napolitani         7.68       7.21           NaN  novodra
#
#      dosage_start  dosage_end           adverse_reaction
# ...

# %%
# as this all problems will be done

# %% [markdown]
# # exploratory data analysis (EDA)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# catagorize your columns

# %% [markdown]
# - numercial=PassengerId, age, fare
# - catagorical=survived, pclass, sex, sibsp, parch, embarked
# - mix=name, ticket, cabin

# %%
 # univariate > bivariate > multivariate > feature engineering

# %%
# univariate : discriptive stats, visualizations, identifying outliers, skewness, conclusions

# %%
# univariate on numerical

# %%
df["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
sns.histplot(df["Age"], bins=16)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.kdeplot(df["Age"])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df["Age"].skew()
# Out:
# 0.38910778230082704

# %%
sns.boxplot(df["Age"])
# Out:
# <Axes: >

# %%
df[df["Age"]>=65]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 280          281         0       3                      Duane, Mr. Frank
# 456          457         0       1             Millet, Mr. Francis Davis
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# ...

# %%
df["Age"].isnull().sum()/len(df["Age"])
# Out:
# 0.19865319865319866

# %%
df["Fare"].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df["Fare"].isnull().sum()
# Out:
# 0

# %%
plt.hist(df["Fare"])
# Out:
# (array([732., 106.,  31.,   2.,  11.,   6.,   0.,   0.,   0.,   3.]),
#  array([  0.     ,  51.23292, 102.46584, 153.69876, 204.93168, 256.1646 ,
#         307.39752, 358.63044, 409.86336, 461.09628, 512.3292 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.kdeplot(df["Fare"])
# Out:
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
df["Fare"].skew()
# Out:
# 4.787316519674893

# %%
sns.boxplot(df["Fare"])
# Out:
# <Axes: >

# %%
df[df["Fare"]>250]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 258          259         1       1                       Ward, Miss. Anna
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 27     male  19.0      3      2     19950  263.0000      C23 C25 C27        S
# ...

# %%
df["Fare"].isnull().sum()
# Out:
# 0

# %%
# univariate on catagorical

# %%
df["Survived"].describe()
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Survived, dtype: float64

# %%
df["Survived"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Survived'>

# %%
df["Survived"].value_counts().plot(kind="pie", autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df["Survived"].isnull().sum()
# Out:
# 0

# %%
df["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df["Pclass"].value_counts().plot(kind="pie", autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df["Pclass"].isnull().sum()
# Out:
# 0

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df["Sex"].value_counts().plot(kind="pie", autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df["Sex"].isnull().sum()
# Out:
# 0

# %%
df["SibSp"].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df["SibSp"].value_counts().plot(kind="pie", autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df["SibSp"].isnull().sum()
# Out:
# 0

# %%
df["Parch"].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
df["Parch"].value_counts().plot(kind="pie", autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df["Embarked"].value_counts().plot(kind="pie", autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
# univariate on mic pe direct nahi hota

# %%
#bivariate on numerical (num-num, num-cat, cat-cat)

# %%
pd.crosstab(df["Survived"], df["Pclass"], normalize="columns")*100
# Out:
# Pclass            1          2          3
# Survived
# 0         37.037037  52.717391  75.763747
# 1         62.962963  47.282609  24.236253

# %%
sns.heatmap(pd.crosstab(df["Survived"], df["Pclass"], normalize="columns")*100)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
pd.crosstab(df["Survived"], df["Sex"], normalize="columns")*100
# Out:
# Sex          female       male
# Survived
# 0         25.796178  81.109185
# 1         74.203822  18.890815

# %%
sns.heatmap(pd.crosstab(df["Survived"], df["Sex"], normalize="columns")*100)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
pd.crosstab(df["Survived"], df["Embarked"], normalize="columns")*100
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %%
sns.heatmap(pd.crosstab(df["Survived"], df["Embarked"], normalize="columns")*100, cmap="viridis")
# Out:
# <Axes: xlabel='Embarked', ylabel='Survived'>

# %%
pd.crosstab(df["Sex"], df["Embarked"], normalize="columns")*100
# Out:
# Embarked          C          Q          S
# Sex
# female    43.452381  46.753247  31.521739
# male      56.547619  53.246753  68.478261

# %%
pd.crosstab(df["Pclass"], df["Embarked"], normalize="columns")*100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665

# %%
df[df["Survived"]==1]["Age"].plot(kind="kde", label="survived")
df[df["Survived"]==0]["Age"].plot(kind="kde", label="dead")

plt.legend()
plt.show()

# %%
df[df["SibSp"]==8]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
df["SibSp"].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8], dtype=int64)

# %%
df1=pd.read_csv("test.csv")

# %%
df=pd.concat([df, df1])

# %%
df[df["Ticket"]=="CA. 2343"]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160       0.0       3         Sage, Master. Thomas Henry    male
# 180          181       0.0       3       Sage, Miss. Constance Gladys  female
# 201          202       0.0       3                Sage, Mr. Frederick    male
# 324          325       0.0       3           Sage, Mr. George John Jr    male
# 792          793       0.0       3            Sage, Miss. Stella Anna  female
# 846          847       0.0       3           Sage, Mr. Douglas Bullen    male
# 863          864       0.0       3  Sage, Miss. Dorothy Edith "Dolly"  female
# 188         1080       NaN       3                    Sage, Miss. Ada  female
# 342         1234       NaN       3              Sage, Mr. John George    male
# 360         1252       NaN       3        Sage, Master. William Henry    male
# 365         1257       NaN       3     Sage, Mrs. John (Annie Bullen)  female
#
# ...

# %%
df["Ticket"].value_counts()
# Out:
# Ticket
# CA. 2343        11
# CA 2144          8
# 1601             8
# PC 17608         7
# S.O.C. 14879     7
#                 ..
# 113792           1
# 36209            1
# 323592           1
# 315089           1
# 359309           1
# Name: count, Length: 929, dtype: int64

# %%
df[df["Ticket"]=="CA 2144"]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 59            60       0.0       3       Goodwin, Master. William Frederick
# 71            72       0.0       3               Goodwin, Miss. Lillian Amy
# 386          387       0.0       3          Goodwin, Master. Sidney Leonard
# 480          481       0.0       3           Goodwin, Master. Harold Victor
# 678          679       0.0       3  Goodwin, Mrs. Frederick (Augusta Tyler)
# 683          684       0.0       3              Goodwin, Mr. Charles Edward
# 139         1031       NaN       3           Goodwin, Mr. Charles Frederick
# 140         1032       NaN       3              Goodwin, Miss. Jessie Allis
#
#         Sex   Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 59     male  11.0      5      2  CA 2144  46.9   NaN        S
# 71   female  16.0      5      2  CA 2144  46.9   NaN        S
# 386    male   1.0      5      2  CA 2144  46.9   NaN        S
# ...

# %%
df["Individual_Fare"]=df["Fare"]/(df["SibSp"]+df["Parch"]+1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[["Fare", "Individual_Fare"]].describe()
# Out:
#               Fare  Individual_Fare
# count  1308.000000      1308.000000
# mean     33.295479        20.518215
# std      51.758668        35.774337
# min       0.000000         0.000000
# 25%       7.895800         7.452767
# 50%      14.454200         8.512483
# 75%      31.275000        24.237500
# max     512.329200       512.329200

# %%
df["Family_size"]=df["SibSp"]+df["Parch"]+1

# %%
df["Family_size"].value_counts()
# Out:
# Family_size
# 1     790
# 2     235
# 3     159
# 4      43
# 6      25
# 5      22
# 7      16
# 11     11
# 8       8
# Name: count, dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def family_size(family_size):
    
    if family_size==1:
        return "Alone"
    
    elif family_size>1 and family_size<5:
        return "Small"
    
    else:
        return "Large"

# %%
df["Family_type"]=df["Family_size"].apply(family_size)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Individual_Fare  \
# 0      0         A/5 21171   7.2500   NaN        S          3.62500
# 1      0          PC 17599  71.2833   C85        C         35.64165
# 2      0  STON/O2. 3101282   7.9250   NaN        S          7.92500
# ...

# %%
pd.crosstab(df["Survived"], df["Family_type"], normalize="columns")
# Out:
# Family_type     Alone    Large     Small
# Survived
# 0.0          0.696462  0.83871  0.421233
# 1.0          0.303538  0.16129  0.578767

# %%
df["Surname"]=df["Name"].str.split(",").str.get(0)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Individual_Fare  \
# 0      0         A/5 21171   7.2500   NaN        S          3.62500
# 1      0          PC 17599  71.2833   C85        C         35.64165
# 2      0  STON/O2. 3101282   7.9250   NaN        S          7.92500
# ...

# %%
df["Title"]=df["Name"].str.split(",").str.get(1).str.split(".").str.get(0)

# %%
df["Title"].value_counts()
# Out:
# Title
#  Mr              757
#  Miss            260
#  Mrs             197
#  Master           61
#  Rev               8
#  Dr                8
#  Col               4
#  Mlle              2
#  Major             2
#  Ms                2
#  Lady              1
#  Sir               1
#  Mme               1
#  Don               1
#  Capt              1
#  the Countess      1
#  Jonkheer          1
#  Dona              1
# Name: count, dtype: int64

# %%
df["Title"]=df["Title"].str.replace("Rev", "Others")
df["Title"]=df["Title"].str.replace("Dr", "Others")
df["Title"]=df["Title"].str.replace("Col", "Others")
df["Title"]=df["Title"].str.replace("Mlle", "Others")
df["Title"]=df["Title"].str.replace("Major", "Others")
df["Title"]=df["Title"].str.replace("Ms", "Others")
df["Title"]=df["Title"].str.replace("Lady", "Others")
df["Title"]=df["Title"].str.replace("Sir", "Others")
df["Title"]=df["Title"].str.replace("Mme", "Others")
df["Title"]=df["Title"].str.replace("Don", "Others")
df["Title"]=df["Title"].str.replace("Capt", "Others")
df["Title"]=df["Title"].str.replace("the Countless", "Others")
df["Title"]=df["Title"].str.replace("Jonkheer", "Others")
df["Title"]=df["Title"].str.replace("Dona", "Others")

# %%
df["Title"].value_counts()
# Out:
# Title
#  Mr              757
#  Miss            260
#  Mrs             197
#  Master           61
#  Others           32
#  the Countess      1
#  Othersa           1
# Name: count, dtype: int64

# %%
pd.crosstab(df["Survived"], df["Title"], normalize="columns")*100
# Out:
# Title      Master      Miss         Mr   Mrs     Others   the Countess
# Survived
# 0.0          42.5  30.21978  84.332689  20.8  57.692308            0.0
# 1.0          57.5  69.78022  15.667311  79.2  42.307692          100.0

# %%
df["Cabin"].fillna("M", inplace=True)

# %%
df["deck"]=df["Cabin"].str[0]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Individual_Fare  \
# 0      0         A/5 21171   7.2500     M        S          3.62500
# 1      0          PC 17599  71.2833   C85        C         35.64165
# 2      0  STON/O2. 3101282   7.9250     M        S          7.92500
# ...

# %%
pd.crosstab(df["deck"], df["Pclass"])
# Out:
# Pclass   1    2    3
# deck
# A       22    0    0
# B       65    0    0
# C       94    0    0
# D       40    6    0
# E       34    4    3
# F        0   13    8
# G        0    0    5
# M       67  254  693
# T        1    0    0

# %%
pd.crosstab(df["deck"], df["Survived"], normalize="index").plot(kind="bar", stacked=True)
# Out:
# <Axes: xlabel='deck'>
